# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gasData=pd.read_csv('natural_gas_dailyPrice.csv')

# %%
gasData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5953 entries, 0 to 5952
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    5953 non-null   object
#  1   Price   5952 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 93.1+ KB

# %%
gasData['Date']=pd.to_datetime(gasData['Date'])

# %%
gasData=gasData.dropna()

# %%
bool=gasData['Price'].isnull()

# %%
bool.value_counts()
# Out:
# Price
# False    5952
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14,8),dpi=200)
sns.scatterplot(data=gasData,x='Date',y='Price')
plt.
# Out:
# <Axes: xlabel='Date', ylabel='Price'>
